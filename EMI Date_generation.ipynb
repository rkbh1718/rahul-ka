# %%
import pandas as pd

# %%
df = pd.read_excel('Data File - Machine Test.xlsx')

# %%
df.head(5)
# Out:
#               lid  emi_amt     type  no of emi 1st EMI Date  Unnamed: 5  \
# 0  LOAN0228644306     1090   Weekly         20   2021-05-05         NaN
# 1  LOAP0262344307     1536  Monthly          5   2021-07-06         NaN
# 2  LOAP0261344307     1064  Monthly         10   2021-05-06         NaN
# 3  LOAP0263044307     1294  Monthly          9   2021-05-06         NaN
# 4  LOAP0264244307     2182  Monthly          5   2021-01-06         NaN
#
#    Unnamed: 6  Unnamed: 7  Unnamed: 8  Unnamed: 9  ...  Unnamed: 707  \
# 0         NaN         NaN         NaN         NaN  ...           NaN
# 1         NaN         NaN         NaN         NaN  ...           NaN
# 2         NaN         NaN         NaN         NaN  ...           NaN
# 3         NaN         NaN         NaN         NaN  ...           NaN
# 4         NaN         NaN         NaN         NaN  ...           NaN
#
#    Unnamed: 708  Unnamed: 709  Unnamed: 710  Unnamed: 711  Unnamed: 712  \
# ...

# %%
df.drop('Unnamed: 7', inplace=True, axis=1)

# %%
df = df.loc[:, ~df.columns.str.contains('^Unnamed')]

# %%
df.head()
# Out:
#               lid  emi_amt     type  no of emi 1st EMI Date
# 0  LOAN0228644306     1090   Weekly         20   2021-05-05
# 1  LOAP0262344307     1536  Monthly          5   2021-07-06
# 2  LOAP0261344307     1064  Monthly         10   2021-05-06
# 3  LOAP0263044307     1294  Monthly          9   2021-05-06
# 4  LOAP0264244307     2182  Monthly          5   2021-01-06
